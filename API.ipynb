# %%
from abc import ABC, abstractmethod
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from binance.spot import Spot
from collections import namedtuple
from datetime import datetime
from operator import itemgetter
from pydash import py_

# %%
class ExchangeAPI(ABC):
    """Класс для работы с биржевым API."""

    @abstractmethod
    def get_historical(self):
        """Получает историю цен."""
        return

    @abstractmethod
    def get_current(self):
        """Получает текущую цену."""
        return

    @abstractmethod
    def info(self):
        """Информация об аккаунте."""
        return

# %%
class BinanceAPI(ExchangeAPI):
    def __init__(self, key, secret, ticker='BTCUSDT'):
        """Класс для работы с Binance API."""
        self._client = Spot(key=key, secret=secret)
        self._ticker = ticker

    def info(self):
        return self._client.account()

    def get_historical(self, interval='1m', limit=None, symbol=None):
        data = self._client.klines(interval=interval,
                                   symbol=symbol if symbol else self._ticker,
                                   limit=limit if limit else 1000)
        df = pd.DataFrame(data=map(lambda d: d[:-1],
                                   filter(lambda d: d[-1] == '0',
                                          data)),
                          columns=['open_dttm',
                                   'open',
                                   'high',
                                   'low',
                                   'close',
                                   'volume',
                                   'close_dttm',
                                   'quote_asset_volume',
                                   'n_trades',
                                   'taker_buy_base_asset_volume',
                                   'taker_buy_quote_asset_volume'])

        df = df.astype(float).assign(open_dttm=df.open_dttm.map(BinanceAPI.from_timestamp),
                                     close_dttm=df.close_dttm.map(BinanceAPI.from_timestamp)).set_index('open_dttm')

        return df

    def get_current(self):
        """TODO"""
        return

    @staticmethod
    def to_timestamp(dttm: datetime):
        return dttm.timestamp() * 1000

    @staticmethod
    def from_timestamp(ts):
        return datetime.fromtimestamp(ts / 1000)

# %%
# %%timeit
b = BinanceAPI(**params)
client = b._client
h = b.get_historical()
# Out:
# 1.19 s ± 342 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
class BinanceAPI(ExchangeAPI):
    def __init__(self, key, secret, ticker='BTCUSDT'):
        """Класс для работы с Binance API."""
        self._client = Spot(key=key, secret=secret)
        self._ticker = ticker

    def info(self):
        return self._client.account()

    def get_historical(self, interval='1m', limit=None, symbol=None):
        data = self._client.klines(interval=interval,
                                   symbol=symbol if symbol else self._ticker,
                                   limit=limit if limit else 1000)
        df = pd.DataFrame(data=data,
                          columns=['open_dttm',
                                   'open',
                                   'high',
                                   'low',
                                   'close',
                                   'volume',
                                   'close_dttm',
                                   'quote_asset_volume',
                                   'n_trades',
                                   'taker_buy_base_asset_volume',
                                   'taker_buy_quote_asset_volume',
                                   'ignore'])

        df = df.astype(float).assign(open_dttm=df.open_dttm.map(BinanceAPI.from_timestamp),
                                     close_dttm=df.close_dttm.map(BinanceAPI.from_timestamp)).set_index('open_dttm')

        return df

    def get_current(self):
        """TODO"""
        return

    @staticmethod
    def to_timestamp(dttm: datetime):
        return dttm.timestamp() * 1000

    @staticmethod
    def from_timestamp(ts):
        return datetime.fromtimestamp(ts / 1000)

# %%
params = dict(key='dXxp9qRq33vVWxmaEVcim1CC0frR7o1Nyh5N1oxm6JuCoBNABN1fb1OBZqoGgKaG',
              secret='29zKsFnbXkEXxuq3yEBPzuUwKfuOEQZ9YgpYzw9tffuFNiPZQLTtGpsbXUx7zF0A')

# %%
# %%timeit
b = BinanceAPI(**params)
client = b._client
h = b.get_historical()
# Out:
# 947 ms ± 235 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
h
# Out:
#                          open      high       low     close    volume  \
# open_dttm
# 2021-11-06 07:39:00  60739.98  60746.48  60695.53  60719.93  33.12127
# 2021-11-06 07:40:00  60719.92  60721.00  60681.00  60689.37  19.30714
# 2021-11-06 07:41:00  60689.37  60770.87  60689.37  60759.09  15.34612
# 2021-11-06 07:42:00  60759.10  60762.86  60717.00  60746.70  28.58301
# 2021-11-06 07:43:00  60746.70  60752.54  60721.50  60726.16  11.53770
# ...                       ...       ...       ...       ...       ...
# 2021-11-07 00:14:00  61488.05  61520.04  61485.82  61519.22  30.18441
# 2021-11-07 00:15:00  61519.21  61529.06  61450.00  61479.69  16.01990
# 2021-11-07 00:16:00  61479.69  61499.99  61466.83  61481.66  13.95952
# 2021-11-07 00:17:00  61481.67  61489.21  61470.76  61477.99   9.02188
# 2021-11-07 00:18:00  61477.99  61477.99  61477.98  61477.99   0.34578
#
#                                  close_dttm  quote_asset_volume  n_trades  \
# open_dttm
# 2021-11-06 07:39:00 2021-11-06 07:39:59.999        2.011066e+06     791.0
# 2021-11-06 07:40:00 2021-11-06 07:40:59.999        1.171994e+06     721.0
# 2021-11-06 07:41:00 2021-11-06 07:41:59.999        9.320609e+05     655.0
# 2021-11-06 07:42:00 2021-11-06 07:42:59.999        1.736305e+06     748.0
# 2021-11-06 07:43:00 2021-11-06 07:43:59.999        7.007629e+05     567.0
# ...                                     ...                 ...       ...
# 2021-11-07 00:14:00 2021-11-07 00:14:59.999        1.856619e+06     759.0
# 2021-11-07 00:15:00 2021-11-07 00:15:59.999        9.848640e+05     787.0
# 2021-11-07 00:16:00 2021-11-07 00:16:59.999        8.582493e+05     446.0
# 2021-11-07 00:17:00 2021-11-07 00:17:59.999        5.546554e+05     448.0
# 2021-11-07 00:18:00 2021-11-07 00:18:59.999        2.125786e+04      40.0
#
#                      taker_buy_base_asset_volume  taker_buy_quote_asset_volume
# open_dttm
# 2021-11-06 07:39:00                      9.92204                  6.024083e+05
# 2021-11-06 07:40:00                      4.65579                  2.825970e+05
# 2021-11-06 07:41:00                     10.46135                  6.353486e+05
# 2021-11-06 07:42:00                     14.57589                  8.854093e+05
# 2021-11-06 07:43:00                      5.18153                  3.146949e+05
# ...                                          ...                           ...
# 2021-11-07 00:14:00                     23.25040                  1.430105e+06
# 2021-11-07 00:15:00                      8.22105                  5.054022e+05
# 2021-11-07 00:16:00                      9.33170                  5.736934e+05
# 2021-11-07 00:17:00                      4.80873                  2.956380e+05
# 2021-11-07 00:18:00                      0.24488                  1.505473e+04
#
# [1000 rows x 10 columns]

# %%
client.time()
# Out:
# {'serverTime': 1636242384421}

# %%
ticker = 'BTCUSDT'

# %%
client.ticker_price(ticker)
# Out:
# {'symbol': 'BTCUSDT', 'price': '61386.70000000'}

# %%
client.exchange_info(ticker)
# Out:
# {'timezone': 'UTC',
#  'serverTime': 1636239823021,
#  'rateLimits': [{'rateLimitType': 'REQUEST_WEIGHT',
#    'interval': 'MINUTE',
#    'intervalNum': 1,
#    'limit': 1200},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'SECOND',
#    'intervalNum': 10,
#    'limit': 50},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'DAY',
#    'intervalNum': 1,
#    'limit': 160000},
#   {'rateLimitType': 'RAW_REQUESTS',
#    'interval': 'MINUTE',
#    'intervalNum': 5,
#    'limit': 6100}],
#  'exchangeFilters': [],
#  'symbols': [{'symbol': 'BTCUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'BTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00001000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00001000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '92.22219477',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']}]}

# %%
client.coin_info()
# Out:
# [{'coin': 'AGLD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Adventure Gold',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AGLD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '13',
#     'withdrawMin': '26',
#     'withdrawMax': '9999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'STPT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Standard Tokenization Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'STPT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '276',
#     'withdrawMin': '552',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'MXN',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Mexican Peso',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'MXN',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'UGX',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Uganda Shilling',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'UGX',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'RENBTC',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'renBTC',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'RENBTC',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.000005',
#     'withdrawMin': '0.00001',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'RENBTC',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.00059',
#     'withdrawMin': '0.0012',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'GLM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Golem',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'GLM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '63',
#     'withdrawMin': '126',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'RAY',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Raydium',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'SOL',
#     'coin': 'RAY',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The Solana blockchain will retain 0.00203928 SOL for your first token deposit. The following deposits will not be charge for any fee.',
#     'specialWithdrawTips': '',
#     'name': 'Solana',
#     'resetAddressStatus': False,
#     'addressRegex': '^[1-9A-HJ-NP-Za-km-z]{32,44}$',
#     'memoRegex': '',
#     'withdrawFee': '0.2',
#     'withdrawMin': '0.4',
#     'withdrawMax': '9999999',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'NEAR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'NEAR Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BNB',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Both a MEMO and an Address are required to successfully deposit your BEP2 tokens to Binance.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.03',
#     'withdrawMin': '0.06',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True},
#    {'network': 'BSC',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.03',
#     'withdrawMin': '0.06',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'NEAR',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'NEAR Protocol',
#     'resetAddressStatus': False,
#     'addressRegex': '^[a-z0-9_-]{1}[a-z0-9_.-]{0,62}[a-z0-9_-]{1}$',
#     'memoRegex': '',
#     'withdrawFee': '0.01',
#     'withdrawMin': '0.2',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 5,
#     'sameAddress': False}]},
#  {'coin': 'AUDIO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Audius',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AUDIO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '13',
#     'withdrawMin': '26',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'HNT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': False,
#   'name': 'Helium',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'HNT',
#     'coin': 'HNT',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'name': 'Helium',
#     'resetAddressStatus': False,
#     'addressRegex': '^(1)[0-9A-za-z]{50}$',
#     'memoRegex': '',
#     'withdrawFee': '0.05',
#     'withdrawMin': '1',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'ADADOWN',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'ADADOWN',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETF',
#     'coin': 'ADADOWN',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'ETF',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'CDT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': False,
#   'name': 'Blox',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'CDT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '198',
#     'withdrawMin': '396',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'SPARTA',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Spartan Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'SPARTA',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will potentially lose your assets if the chosen platform does not support refund of wrongfully deposited assets. Please note that you are withdrawing SPARTAv2 which is subject to a fee burn. For more information, please refer to: ##https://spartanprotocol.medium.com/spartav2-token-fee-burn-97e5441da98e##',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '2',
#     'withdrawMin': '4',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'SUSD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'sUSD',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'SUSD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '15',
#     'withdrawMin': '30',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'FARM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Harvest Finance',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'FARM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.0018',
#     'withdrawMin': '0.0036',
#     'withdrawMax': '9999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'FARM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.22',
#     'withdrawMin': '0.44',
#     'withdrawMax': '9999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'AION',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'AION',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'AION',
#     'coin': 'AION',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Aion',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{64}$',
#     'memoRegex': '',
#     'withdrawFee': '0.1',
#     'withdrawMin': '0.2',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 60,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'AION',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'Network swapped, ERC20 withdrawal closed.',
#     'specialTips': 'This deposit address supports ERC20 tokens. We will automatically convert your tokens to the Mainnet.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '197',
#     'withdrawMin': '394',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'NPXS',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Old Pundi X',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'NPXS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '4915',
#     'withdrawMin': '9830',
#     'withdrawMax': '9900000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'DGB',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'DigiByte',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'DGB',
#     'coin': 'DGB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'DigiByte',
#     'resetAddressStatus': False,
#     'addressRegex': '^[DS][a-km-zA-HJ-NP-Z1-9]{25,34}$|^(dgb1)[0-9A-Za-z]{39,59}$',
#     'memoRegex': '',
#     'withdrawFee': '0.2',
#     'withdrawMin': '0.4',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 10,
#     'unLockConfirm': 50,
#     'sameAddress': False}]},
#  {'coin': 'ZRX',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': '0x',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'ZRX',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '30',
#     'withdrawMin': '60',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BCD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Bitcoin Diamond',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BCD',
#     'coin': 'BCD',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Bitcoin Diamond',
#     'resetAddressStatus': False,
#     'addressRegex': '^[13][a-km-zA-HJ-NP-Z1-9]{25,34}$',
#     'memoRegex': '',
#     'withdrawFee': '0.01',
#     'withdrawMin': '0.02',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 6,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'EASY',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'EasyFi',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BSC',
#     'coin': 'EASY',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Sorry, we do not support deposits for this asset.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.017',
#     'withdrawMin': '0.034',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'EASY',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Sorry, we do not support deposits for this asset.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '2',
#     'withdrawMin': '4',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'WING',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Wing Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ONT',
#     'coin': 'WING',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ontology',
#     'resetAddressStatus': False,
#     'addressRegex': '^(A)[A-Za-z0-9]{33}$',
#     'memoRegex': '',
#     'withdrawFee': '0.0027',
#     'withdrawMin': '0.0054',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 5,
#     'sameAddress': False}]},
#  {'coin': 'WNXM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Wrapped NXM',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'WNXM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.55',
#     'withdrawMin': '1.1',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BCH',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Bitcoin Cash',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BCH',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Bitcoin Cash',
#     'resetAddressStatus': False,
#     'addressRegex': '^[13][a-km-zA-HJ-NP-Z1-9]{25,34}$|^[0-9A-Za-z]{42,42}$',
#     'memoRegex': '',
#     'withdrawFee': '0.001',
#     'withdrawMin': '0.002',
#     'withdrawMax': '10000000000',
#     'minConfirm': 2,
#     'unLockConfirm': 6,
#     'sameAddress': False},
#    {'network': 'BNB',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit BCH BEP2 tokens to your Binance account.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.00051',
#     'withdrawMin': '0.001',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True},
#    {'network': 'BSC',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.00051',
#     'withdrawMin': '0.001',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': 'This deposit address supports ERC20 BBCH tokens. Please ensure your destination address supports BBCH tokens under the contract address ending in 65f1b.',
#     'specialWithdrawTips': 'The network you have selected is ERC20-BBCH. Please ensure that the withdrawal address supports the ERC20-BBCH. You will potentially lose your assets if the chosen platform does not support refund of wrongfully deposited assets.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.06',
#     'withdrawMin': '0.12',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'JST',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'JUST',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'JST',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '3.69',
#     'withdrawMin': '7.38',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'TRX',
#     'coin': 'JST',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Tron (TRC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^T[1-9A-HJ-NP-Za-km-z]{33}$',
#     'memoRegex': '',
#     'withdrawFee': '50',
#     'withdrawMin': '100',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'ADAUP',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'ADAUP',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETF',
#     'coin': 'ADAUP',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'ETF',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'HOT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Holo',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'HOT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Holo (ticker: HOT). Please ensure you are depositing Holo (HOT) tokens under the contract address ending in 526e2.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '2527',
#     'withdrawMin': '5054',
#     'withdrawMax': '9900000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'AR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Arweave',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'AR',
#     'coin': 'AR',
#     'withdrawIntegerMultiple': '0.00001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Arweave',
#     'resetAddressStatus': False,
#     'addressRegex': '^[0-9a-z-A-Z\\-\\_]{43}$',
#     'memoRegex': '',
#     'withdrawFee': '0.03',
#     'withdrawMin': '0.1',
#     'withdrawMax': '9999999',
#     'minConfirm': 20,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'IRIS',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'IRISnet',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'IRIS',
#     'coin': 'IRIS',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Both a MEMO and an Address are required to successfully deposit your IRIS to Binance',
#     'name': 'IRISnet',
#     'resetAddressStatus': False,
#     'addressRegex': '^(iaa1)[0-9a-z]{38}$',
#     'memoRegex': '',
#     'withdrawFee': '1',
#     'withdrawMin': '2',
#     'withdrawMax': '10000000000',
#     'minConfirm': 10,
#     'unLockConfirm': 15,
#     'sameAddress': True}]},
#  {'coin': 'RAMP',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'RAMP',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'RAMP',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '1.07',
#     'withdrawMin': '2.14',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'RAMP',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '124',
#     'withdrawMin': '248',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BCX',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'BitcoinX',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BCX',
#     'coin': 'BCX',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Sorry, we do not support deposits for this asset.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'BitcoinX',
#     'resetAddressStatus': False,
#     'addressRegex': '^(X)[0-9A-za-z]{33}$',
#     'memoRegex': '',
#     'withdrawFee': '0.5',
#     'withdrawMin': '0.5',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 2,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'SEK',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'Swedish Kroner ',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'SEK',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'We have disabled deposits as our systems are currently undergoing maintenance.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'TRIG',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'Triggers',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'TRIG',
#     'coin': 'TRIG',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Sorry, but this asset has been delisted. We cannot process deposits for this asset.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'name': 'Triggers',
#     'resetAddressStatus': False,
#     'addressRegex': '^[13][a-km-zA-HJ-NP-Z1-9]{25,34}$',
#     'memoRegex': '',
#     'withdrawFee': '50',
#     'withdrawMin': '51',
#     'withdrawMax': '10000000000',
#     'minConfirm': 2,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'RCN',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Ripio Credit Network',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'RCN',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'We have disabled deposits as our systems are currently undergoing maintenance.',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Ripio Credit Network. Please ensure you are depositing Ripio Credit Network (RCN) tokens under the contract address ending in 375a6.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '539',
#     'withdrawMin': '1078',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'COVER',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'COVER Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'COVER',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please ensure you are depositing ERC20 COVER tokens under the contract address ending in Bd8713',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.005',
#     'withdrawMin': '0.01',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'FLM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Flamingo',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'NEO',
#     'coin': 'FLM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'NEP5',
#     'resetAddressStatus': False,
#     'addressRegex': '^(A)[A-Za-z0-9]{33}$',
#     'memoRegex': '',
#     'withdrawFee': '0.5',
#     'withdrawMin': '2',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 5,
#     'sameAddress': False}]},
#  {'coin': 'GNO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Gnosis',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'GNO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.074',
#     'withdrawMin': '0.15',
#     'withdrawMax': '9999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'VITE',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'VITE',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'VITE',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '2.27',
#     'withdrawMin': '4.54',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'VITE',
#     'coin': 'VITE',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Both a MEMO and an Address are required to successfully deposit your VITE to Binance.',
#     'name': 'VITE',
#     'resetAddressStatus': False,
#     'addressRegex': '^(vite_)[a-z0-9]{50}$',
#     'memoRegex': '\\w{0,120}',
#     'withdrawFee': '1',
#     'withdrawMin': '2',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 150,
#     'unLockConfirm': 0,
#     'sameAddress': True}]},
#  {'coin': 'GNT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': False,
#   'name': 'Golem',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'GNT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'Smart contract swap in progress. Withdrawals are temporarily suspended.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '20',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BKRW',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Binance KRW',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BNB',
#     'coin': 'BKRW',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Sorry, but this asset has been delisted. We cannot process deposits for this asset.',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit BEP2-BKRW tokens to your Binance account.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0',
#     'withdrawMin': '20',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True}]},
#  {'coin': 'CFX',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Conflux Network',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'CFX',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.87',
#     'withdrawMin': '1.74',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'XPR',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Proton',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'XPR',
#     'withdrawIntegerMultiple': '0.0001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'We have disabled deposits as our systems are currently undergoing maintenance.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '1',
#     'withdrawMin': '2',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'SFP',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'SafePal',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'SFP',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.19',
#     'withdrawMin': '0.38',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'DIA',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'DIA',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'DIA',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.17',
#     'withdrawMin': '0.34',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
# ...
#     'withdrawFee': '389',
#     'withdrawMin': '778',
#     'withdrawMax': '9999999',
#     'depositDust': '0.00000001',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'VIB',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Viberate',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'VIB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '684',
#     'withdrawMin': '1368',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'VIA',
#   'depositAllEnable': True,
#   'withdrawAllEnable': False,
#   'name': 'Viacoin',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'VIA',
#     'coin': 'VIA',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'name': 'Viacoin',
#     'resetAddressStatus': False,
#     'addressRegex': '((V|E)[A-Za-z0-9]{33})|(via1[qpzry9x8gf2tvdw0s3jn54khce6mua7l]{39})',
#     'memoRegex': '',
#     'withdrawFee': '0.01',
#     'withdrawMin': '0.02',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 50,
#     'sameAddress': False}]},
#  {'coin': 'FIS',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Stafi',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'FIS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.18',
#     'withdrawMin': '0.36',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'FIS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '20',
#     'withdrawMin': '40',
#     'withdrawMax': '9900000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BAR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'FC Barcelona Fan Token BAR',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'CHZ',
#     'coin': 'BAR',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'Only CHZ network withdrawals supported. Withdrawing to an address that is not a CHZ network address will result the LOSS of your funds.',
#     'name': 'Chiliz Chain (CHZ)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '1',
#     'withdrawMax': '9999999',
#     'minConfirm': 15,
#     'unLockConfirm': 30,
#     'sameAddress': False}]},
#  {'coin': 'RAD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Radicle',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'RAD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '3.36',
#     'withdrawMin': '6.72',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BAT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Basic Attention Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BNB',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Basic Attention Token (BAT). Both a MEMO and an Address are required to successfully deposit your BEP2 tokens to Binance.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.31',
#     'withdrawMin': '0.62',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True},
#    {'network': 'BSC',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Basic Attention Token. Please ensure you are depositing Basic Attention Token (BAT) tokens under the contract address ending in 9766e.',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.31',
#     'withdrawMin': '0.62',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Basic Attention Token. Please ensure you are depositing Basic Attention Token (BAT) tokens under the contract address ending in 887ef.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '36',
#     'withdrawMin': '72',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'VRAB',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Verasity',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BNB',
#     'coin': 'VRAB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit VRAB BEP2 tokens to your Binance account.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '100',
#     'withdrawMin': '200',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True},
#    {'network': 'ETH',
#     'coin': 'VRAB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Sorry, we do not support deposits for this asset.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '300',
#     'withdrawMin': '600',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'AKRO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Akropolis',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AKRO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '878',
#     'withdrawMin': '1756',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'NZD',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'New Zealand Dollar',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'NZD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'We have disabled deposits as our systems are currently undergoing maintenance.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'MOVR',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'Moonriver',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'MOVR',
#     'coin': 'MOVR',
#     'withdrawIntegerMultiple': '0.00001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'We are preparing the wallet for deposit.',
#     'withdrawDesc': 'We are preparing the wallet for withdrawal.',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Moonriver',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0.00001',
#     'withdrawMax': '9999999',
#     'minConfirm': 30,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'XMR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Monero',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'XMR',
#     'coin': 'XMR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Monero',
#     'resetAddressStatus': False,
#     'addressRegex': '^[48][a-zA-Z|\\d]{94}([a-zA-Z|\\d]{11})?$',
#     'memoRegex': '',
#     'withdrawFee': '0.0001',
#     'withdrawMin': '0.0002',
#     'withdrawMax': '10000000000',
#     'minConfirm': 3,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': '1INCHDOWN',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': '1INCHDOWN',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETF',
#     'coin': '1INCHDOWN',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Not support deposit',
#     'withdrawDesc': 'Not support withdrawal',
#     'specialTips': '',
#     'name': 'ETF',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'COTI',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'COTI',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BNB',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit COTI BEP2 tokens to your Binance account.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.56',
#     'withdrawMin': '1.12',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True},
#    {'network': 'BSC',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '0.56',
#     'withdrawMin': '1.12',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'memoRegex': '',
#     'withdrawFee': '65',
#     'withdrawMin': '130',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]}]

# %%
label_data(k)
# Out:
# {'open_dttm': 1636241160000,
#  'open': '61395.64000000',
#  'high': '61408.07000000',
#  'low': '61388.25000000',
#  'close': '61400.93000000',
#  'volume': '6.44457000',
#  'close_dttm': 1636241219999,
#  'quote_asset_volume': '395674.31873870',
#  'n_trades': 379,
#  'taker_buy_base_asset_volume': '2.94665000',
#  'taker_buy_quote_asset_volume': '180916.69586480',
#  'ignore': '0'}

# %%
k = client.klines('BTCUSDT', interval='1m', limit=3)
k
# Out:
# [[1636241400000,
#   '61396.90000000',
#   '61409.77000000',
#   '61394.13000000',
#   '61407.16000000',
#   '10.72082000',
#   1636241459999,
#   '658300.28240630',
#   383,
#   '6.60842000',
#   '405779.45657730',
#   '0'],
#  [1636241460000,
#   '61407.17000000',
#   '61409.99000000',
#   '61398.44000000',
#   '61402.94000000',
#   '13.96139000',
#   1636241519999,
#   '857278.13619340',
#   441,
#   '7.31295000',
#   '449039.95902040',
#   '0'],
#  [1636241520000,
#   '61402.94000000',
#   '61408.11000000',
#   '61397.46000000',
#   '61397.47000000',
#   '7.03516000',
#   1636241579999,
#   '431976.75429440',
#   223,
#   '1.92497000',
#   '118200.31441910',
#   '0']]

# %%
# Out:
#               0               1               2               3   \
# 0  1636241400000  61396.90000000  61409.77000000  61394.13000000
# 1  1636241460000  61407.17000000  61409.99000000  61398.44000000
# 2  1636241520000  61402.94000000  61408.11000000  61397.46000000
#
#                4            5              6                7    8   \
# 0  61407.16000000  10.72082000  1636241459999  658300.28240630  383
# 1  61402.94000000  13.96139000  1636241519999  857278.13619340  441
# 2  61397.47000000   7.03516000  1636241579999  431976.75429440  223
#
#            9                10 11
# 0  6.60842000  405779.45657730  0
# 1  7.31295000  449039.95902040  0
# 2  1.92497000  118200.31441910  0

# %%
[*map(BinanceAPI.from_timestamp, k)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/583592934.py in <module>
# ----> 1 [*map(BinanceAPI.from_timestamp, k)]
#
# /tmp/ipykernel_35/3479696553.py in from_timestamp(ts)
#      16     @staticmethod
#      17     def from_timestamp(ts):
# ---> 18         return datetime.fromtimestamp(ts / 1000)
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
BinanceAPI.from_timestamp(t)
# Out:
# datetime.datetime(2021, 11, 6, 23, 22)
